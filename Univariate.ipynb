# %% [markdown]
# <a href="https://colab.research.google.com/github/V-Nayak/New-/blob/main/Univariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA using Univariate Analysis on Single Column
# On Numerical, Categorical Data
# file Titanic Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv("/survived.csv")

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
df.value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# **So here we can see that there aree higher chances of people belonging from 25 years age category !!**

# %%
df['Age'].skew()
# Out:
# 0.4573612871503845

# %% [markdown]
# So here...zero indicates perfectly symmetrical data..positive numbers indicates data is rightly skewd while negative numbers denotes data is skewed to left.
